# %%
import pandas as pd

data = {
    "Name": [
        "Anish", "Amit", "Priya", "Neha", "Rahul",
        "Sneha", "Karan", "Rohan", "Amit", "Riya",
        "Vikas", "Anjali", "Rohit", "Kartik", "Arjun",
        "Meera", "Sahil", "Aisha", "Yash", "Anil"
    ],

    "Age": [
        21, 19, 22, 20, 23,
        None, 21, 20, 19, 22,
        24, 21, 20, 23, 22,
        21, None, 20, 19, 22
    ],

    "Gender": [
        "Male", "Male", "Female", "Female", "Male",
        "Female", "Male", "Female", "Male", "Female",
        "Male", "Female", "Male", "Female", "Male",
        "Female", "Male", "Female", "Male", "Female"
    ],

    "City": [
        "Mumbai", "Pune", "Mumbai", "Pune", "Nashik",
        "Pune", "Mumbai", "Nashik", "Pune", "Mumbai",
        "Pune", "Nashik", "Mumbai", "Pune", "Nashik",
        "Mumbai", "Pune", "Nashik", "Mumbai", "Pune"
    ],

    "Course": [
        "Python", "Java", "Python", "C++", "Python",
        "Java", "C++", "Python", "Java", "Java",
        "Python", "C++", "Java", "Python", "C++",
        "Java", "Python", "Java", "C++", "Python"
    ],

    "Marks": [
        85, 76, 92, 68, 81,
        None, 74, 90, 76, 88,
        95, 79, 82, 91, 65,
        87, 72, 84, 77, 93
    ],

    "Attendance": [
        95, 88, 97, 91, 89,
        93, 85, 96, 88, None,
        98, 87, 92, 94, 82,
        90, 86, None, 89, 97
    ],

    "Purchased": [
        "Yes", "No", "Yes", "No", "Yes",
        "No", "Yes", "Yes", "No", "Yes",
        "Yes", "No", "Yes", "Yes", "No",
        "Yes", "No", "Yes", "No", "Yes"
    ]
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name   Age  Gender    City  Course  Marks  Attendance Purchased
# 0    Suraj  21.0    Male  Mumbai  Python   85.0        95.0       Yes
# 1     Amit  19.0    Male    Pune    Java   76.0        88.0        No
# 2    Priya  22.0  Female  Mumbai  Python   92.0        97.0       Yes
# 3     Neha  20.0  Female    Pune     C++   68.0        91.0        No
# 4    Rahul  23.0    Male  Nashik  Python   81.0        89.0       Yes
# 5    Sneha   NaN  Female    Pune    Java    NaN        93.0        No
# 6    Karan  21.0    Male  Mumbai     C++   74.0        85.0       Yes
# 7    Pooja  20.0  Female  Nashik  Python   90.0        96.0       Yes
# 8     Amit  19.0    Male    Pune    Java   76.0        88.0        No
# 9     Riya  22.0  Female  Mumbai    Java   88.0         NaN       Yes
# 10   Vikas  24.0    Male    Pune  Python   95.0        98.0       Yes
# 11  Anjali  21.0  Female  Nashik     C++   79.0        87.0        No
# 12   Rohit  20.0    Male  Mumbai    Java   82.0        92.0       Yes
# 13   Komal  23.0  Female    Pune  Python   91.0        94.0       Yes
# 14   Arjun  22.0    Male  Nashik     C++   65.0        82.0        No
# 15   Meera  21.0  Female  Mumbai    Java   87.0        90.0       Yes
# 16   Sahil   NaN    Male    Pune  Python   72.0        86.0        No
# 17   Aisha  20.0  Female  Nashik    Java   84.0         NaN       Yes
# 18    Yash  19.0    Male  Mumbai     C++   77.0        89.0        No
# 19  Nikita  22.0  Female    Pune  Python   93.0        97.0       Yes

# %%
df.fillna(0)
# Out:
#       Name   Age  Gender    City  Course  Marks  Attendance Purchased
# 0    Suraj  21.0    Male  Mumbai  Python   85.0        95.0       Yes
# 1     Amit  19.0    Male    Pune    Java   76.0        88.0        No
# 2    Priya  22.0  Female  Mumbai  Python   92.0        97.0       Yes
# 3     Neha  20.0  Female    Pune     C++   68.0        91.0        No
# 4    Rahul  23.0    Male  Nashik  Python   81.0        89.0       Yes
# 5    Sneha   0.0  Female    Pune    Java    0.0        93.0        No
# 6    Karan  21.0    Male  Mumbai     C++   74.0        85.0       Yes
# 7    Pooja  20.0  Female  Nashik  Python   90.0        96.0       Yes
# 8     Amit  19.0    Male    Pune    Java   76.0        88.0        No
# 9     Riya  22.0  Female  Mumbai    Java   88.0         0.0       Yes
# 10   Vikas  24.0    Male    Pune  Python   95.0        98.0       Yes
# 11  Anjali  21.0  Female  Nashik     C++   79.0        87.0        No
# 12   Rohit  20.0    Male  Mumbai    Java   82.0        92.0       Yes
# 13   Komal  23.0  Female    Pune  Python   91.0        94.0       Yes
# 14   Arjun  22.0    Male  Nashik     C++   65.0        82.0        No
# 15   Meera  21.0  Female  Mumbai    Java   87.0        90.0       Yes
# 16   Sahil   0.0    Male    Pune  Python   72.0        86.0        No
# 17   Aisha  20.0  Female  Nashik    Java   84.0         0.0       Yes
# 18    Yash  19.0    Male  Mumbai     C++   77.0        89.0        No
# 19  Nikita  22.0  Female    Pune  Python   93.0        97.0       Yes

# %%
df["Marks"]=df["Marks"].fillna(df["Marks"].mean())

# %%
print(df)
# Out:
#       Name   Age  Gender    City  Course      Marks  Attendance Purchased
# 0    Suraj  21.0    Male  Mumbai  Python  85.000000        95.0       Yes
# 1     Amit  19.0    Male    Pune    Java  76.000000        88.0        No
# 2    Priya  22.0  Female  Mumbai  Python  92.000000        97.0       Yes
# 3     Neha  20.0  Female    Pune     C++  68.000000        91.0        No
# 4    Rahul  23.0    Male  Nashik  Python  81.000000        89.0       Yes
# 5    Sneha   NaN  Female    Pune    Java  81.842105        93.0        No
# 6    Karan  21.0    Male  Mumbai     C++  74.000000        85.0       Yes
# 7    Pooja  20.0  Female  Nashik  Python  90.000000        96.0       Yes
# 8     Amit  19.0    Male    Pune    Java  76.000000        88.0        No
# 9     Riya  22.0  Female  Mumbai    Java  88.000000         NaN       Yes
# 10   Vikas  24.0    Male    Pune  Python  95.000000        98.0       Yes
# 11  Anjali  21.0  Female  Nashik     C++  79.000000        87.0        No
# 12   Rohit  20.0    Male  Mumbai    Java  82.000000        92.0       Yes
# 13   Komal  23.0  Female    Pune  Python  91.000000        94.0       Yes
# 14   Arjun  22.0    Male  Nashik     C++  65.000000        82.0        No
# 15   Meera  21.0  Female  Mumbai    Java  87.000000        90.0       Yes
# 16   Sahil   NaN    Male    Pune  Python  72.000000        86.0        No
# 17   Aisha  20.0  Female  Nashik    Java  84.000000         NaN       Yes
# 18    Yash  19.0    Male  Mumbai     C++  77.000000        89.0        No
# 19  Nikita  22.0  Female    Pune  Python  93.000000        97.0       Yes

# %%
print(df["Marks"].min())
# Out:
# 65.0

# %%
print(df["Marks"].max())
# Out:
# 95.0

# %%
print(df["Marks"].mean())
# Out:
# 81.84210526315789

# %%
print(df["Marks"].sum())
# Out:
# 1636.842105263158

# %%
print(df["Course"].unique())
# Out:
# <StringArray>
# ['Python', 'Java', 'C++']
# Length: 3, dtype: str

# %%
print(df["City"].value_counts())
# Out:
# City
# Pune      8
# Mumbai    7
# Nashik    5
# Name: count, dtype: int64

# %%
print(df.groupby("City")["Marks"].mean())
# Out:
# City
# Mumbai    83.571429
# Nashik    79.800000
# Pune      81.605263
# Name: Marks, dtype: float64

# %%
print(df.groupby("City")["Marks"].agg(["min","max","sum","mean"]))
# Out:
#          min   max         sum       mean
# City
# Mumbai  74.0  92.0  585.000000  83.571429
# Nashik  65.0  90.0  399.000000  79.800000
# Pune    68.0  95.0  652.842105  81.605263

# %%
df["Gender"]=df["Gender"].replace({"Male":0,"Female":1})

# %%
print(df)
# Out:
#       Name   Age Gender    City  Course      Marks  Attendance Purchased
# 0    Suraj  21.0      0  Mumbai  Python  85.000000        95.0       Yes
# 1     Amit  19.0      0    Pune    Java  76.000000        88.0        No
# 2    Priya  22.0      1  Mumbai  Python  92.000000        97.0       Yes
# 3     Neha  20.0      1    Pune     C++  68.000000        91.0        No
# 4    Rahul  23.0      0  Nashik  Python  81.000000        89.0       Yes
# 5    Sneha   NaN      1    Pune    Java  81.842105        93.0        No
# 6    Karan  21.0      0  Mumbai     C++  74.000000        85.0       Yes
# 7    Pooja  20.0      1  Nashik  Python  90.000000        96.0       Yes
# 8     Amit  19.0      0    Pune    Java  76.000000        88.0        No
# 9     Riya  22.0      1  Mumbai    Java  88.000000         NaN       Yes
# 10   Vikas  24.0      0    Pune  Python  95.000000        98.0       Yes
# 11  Anjali  21.0      1  Nashik     C++  79.000000        87.0        No
# 12   Rohit  20.0      0  Mumbai    Java  82.000000        92.0       Yes
# 13   Komal  23.0      1    Pune  Python  91.000000        94.0       Yes
# 14   Arjun  22.0      0  Nashik     C++  65.000000        82.0        No
# 15   Meera  21.0      1  Mumbai    Java  87.000000        90.0       Yes
# 16   Sahil   NaN      0    Pune  Python  72.000000        86.0        No
# 17   Aisha  20.0      1  Nashik    Java  84.000000         NaN       Yes
# 18    Yash  19.0      0  Mumbai     C++  77.000000        89.0        No
# 19  Nikita  22.0      1    Pune  Python  93.000000        97.0       Yes

# %%
X= df[["City","Marks","Age"]]
Y=df[["Purchased"]]
print(X)
print(Y)
# Out:
#       City      Marks   Age
# 0   Mumbai  85.000000  21.0
# 1     Pune  76.000000  19.0
# 2   Mumbai  92.000000  22.0
# 3     Pune  68.000000  20.0
# 4   Nashik  81.000000  23.0
# 5     Pune  81.842105   NaN
# 6   Mumbai  74.000000  21.0
# 7   Nashik  90.000000  20.0
# 8     Pune  76.000000  19.0
# 9   Mumbai  88.000000  22.0
# 10    Pune  95.000000  24.0
# 11  Nashik  79.000000  21.0
# 12  Mumbai  82.000000  20.0
# 13    Pune  91.000000  23.0
# 14  Nashik  65.000000  22.0
# 15  Mumbai  87.000000  21.0
# 16    Pune  72.000000   NaN
# 17  Nashik  84.000000  20.0
# 18  Mumbai  77.000000  19.0
# 19    Pune  93.000000  22.0
#    Purchased
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
# 5         No
# 6        Yes
# 7        Yes
# 8         No
# 9        Yes
# 10       Yes
# 11        No
# 12       Yes
# 13       Yes
# 14        No
# 15       Yes
# 16        No
# 17       Yes
# 18        No
# 19       Yes
